# %%
import control as crtl
import matplotlib.pyplot as plt

# %%
# Define the transfer function
# H(s) = 1 / (s^4 + 2s^3 + 3s^2 + 2s + 0)
numerator = [1]
denominator = [1, 2, 3, 2, 0]
system = control.TransferFunction(numerator, denominator)

# %%
# Calculate the poles and zeros of the system
poles = control.poles(system)   # Added the 's'
zeros = control.zeros(system)   # Added the 's'

# %%
print("System Transfer Function:")
print(sys)

# Calculate step response and metrics for the CLOSED LOOP
t, y = ct.step_response(sys_cl)
info = ct.step_info(sys_cl)



print(f"Steady-state Value: {y[-1]:.4f}") # Should be approx 1.0
print(f"Overshoot:          {info['Overshoot']:.2f}%")
print(f"Settling Time:      {info['SettlingTime']:.2f} s")
# Out:
# System Transfer Function:
# <TransferFunction>: sys[1]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#               1
#   -------------------------
#   s^4 + 2 s^3 + 3 s^2 + 2 s
# Steady-state Value: 1.0080
# Overshoot:          27.67%
# Settling Time:      10.75 s

# %%
# Plot Step Response
plt.figure()
t, y = ct.step_response(sys)
plt.plot(t, y)
plt.title("Step Response")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)

plt.show()

# %%
# Plot Pole-Zero Map
plt.figure(figsize=(8, 6))
ct.pzmap(sys, grid=True)
plt.title('Pole-Zero Map')
plt.grid(True)
plt.show()
